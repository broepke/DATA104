# %%
import pandas as pd

# %%
fb = pd.read_csv('Facebook FriendsCSV.csv', skiprows=2)

# %%
fb.describe()
# Out:
#           Friend          Age     # of Tags      Albums     Gender   \
# count  715.000000  715.000000    715.000000  715.000000  715.000000
# mean   358.000000   24.406993    458.096503   18.952448    0.541259
# std    206.547008    6.969578    720.835481   22.502860    0.517932
# min      1.000000   13.000000      0.000000    0.000000    0.000000
# 25%    179.500000   21.000000     75.500000    6.000000    0.000000
# 50%    358.000000   22.000000    250.000000   12.000000    1.000000
# 75%    536.500000   25.000000    566.500000   22.500000    1.000000
# max    715.000000   81.000000  10460.000000  172.000000    2.000000
#
#               Emp     Profile       Cover  Orientation  Relationship  \
# count  715.000000  715.000000  715.000000   715.000000    715.000000
# mean     0.745455    0.917483    0.507692     0.956643      0.492308
# std      0.435910    0.275344    0.500291     0.203801      0.500291
# min      0.000000    0.000000    0.000000     0.000000      0.000000
# ...

# %%
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715 entries, 0 to 714
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Friend        715 non-null    int64
#  1   Age           715 non-null    int64
#  2   Photos        715 non-null    object
#  3   # of Tags     715 non-null    int64
#  4   Albums        715 non-null    int64
#  5   Gender        715 non-null    int64
#  6   Emp           715 non-null    int64
#  7   Profile       715 non-null    int64
#  8   Cover         715 non-null    int64
#  9   Orientation   715 non-null    int64
#  10  Relationship  715 non-null    int64
#  11  Posts         715 non-null    int64
#  12  Replies       715 non-null    int64
#  13  MidWest       715 non-null    int64
#  14  Seast         715 non-null    int64
#  15  West          715 non-null    int64
#  16  Children      715 non-null    int64
#  17  Likes         715 non-null    int64
# ...
